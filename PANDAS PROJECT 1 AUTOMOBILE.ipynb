# %%
import pandas as pd

# %%
data = pd.read_csv('automobiledata.csv')

# %%
data
# Out:
#                                           name  year  sellprice  kmdriven  \
# 0                       Maruti Swift Dzire VDI  2014     450000    145500
# 1                 Skoda Rapid 1.5 TDI Ambition  2014     370000    120000
# 2                     Honda City 2017-2020 EXi  2006     158000    140000
# 3                    Hyundai i20 Sportz Diesel  2010     225000    127000
# 4                       Maruti Swift VXI BSIII  2007     130000    120000
# ..                                         ...   ...        ...       ...
# 94                 Maruti Zen Estilo LXI BSIII  2009     175000     55500
# 95  Hyundai i20 Asta Optional with Sunroof 1.2  2013     525000     61500
# 96                      Maruti Swift Dzire LDI  2016     600000    150000
# 97        Hyundai Xcent 1.2 Kappa SX Option AT  2016     565000     72000
# 98                        Maruti Alto LX BSIII  2008     120000     68000
#
#       fuel  sellertype transmission         owner     mileage   engine  \
# ...

# %% [markdown]
# # Display top 10 rows of the Dataset

# %%
data.head(10)
# Out:
#                                    name  year  sellprice  kmdriven    fuel  \
# 0                Maruti Swift Dzire VDI  2014     450000    145500  Diesel
# 1          Skoda Rapid 1.5 TDI Ambition  2014     370000    120000  Diesel
# 2              Honda City 2017-2020 EXi  2006     158000    140000  Petrol
# 3             Hyundai i20 Sportz Diesel  2010     225000    127000  Diesel
# 4                Maruti Swift VXI BSIII  2007     130000    120000  Petrol
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017     440000     45000  Petrol
# 6          Maruti Wagon R LXI DUO BSIII  2007      96000    175000     LPG
# 7                    Maruti 800 DX BSII  2001      45000      5000  Petrol
# 8                      Toyota Etios VXD  2011     350000     90000  Diesel
# 9  Ford Figo Diesel Celebration Edition  2013     200000    169000  Diesel
#
#    sellertype transmission         owner     mileage   engine    maxpower  \
# ...

# %% [markdown]
# # Display last 10 rows of the Dataset

# %%
data.tail(10)
# Out:
#                                           name  year  sellprice  kmdriven  \
# 89                   Maruti Omni 8 Seater BSIV  2017     280000     32000
# 90                 Maruti Wagon R LXI LPG BSIV  2010     225000     44000
# 91         Volkswagen Polo 1.2 MPI Comfortline  2015     455000     42000
# 92                      Hyundai i10 Magna 1.1L  2015     351000     45000
# 93            Volkswagen Vento Petrol Highline  2012     535000     12000
# 94                 Maruti Zen Estilo LXI BSIII  2009     175000     55500
# 95  Hyundai i20 Asta Optional with Sunroof 1.2  2013     525000     61500
# 96                      Maruti Swift Dzire LDI  2016     600000    150000
# 97        Hyundai Xcent 1.2 Kappa SX Option AT  2016     565000     72000
# 98                        Maruti Alto LX BSIII  2008     120000     68000
#
#       fuel  sellertype transmission         owner     mileage   engine  \
# 89  Petrol      Dealer       Manual   First Owner   14.0 kmpl   796 CC
# ...

# %% [markdown]
# # Check Datatypes of each columns

# %%
data.dtypes
# Out:
# name             object
# year              int64
# sellprice         int64
# kmdriven          int64
# fuel             object
# sellertype       object
# transmission     object
# owner            object
# mileage          object
# engine           object
# maxpower         object
# torque           object
# seats           float64
# dtype: object

# %% [markdown]
# # Check Null Values in the dataset

# %%
data.isnull().sum()
# Out:
# name            0
# year            0
# sellprice       0
# kmdriven        0
# fuel            0
# sellertype      0
# transmission    0
# owner           0
# mileage         4
# engine          4
# maxpower        4
# torque          4
# seats           4
# dtype: int64

# %% [markdown]
# # Visualize The Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Lets Find percentage of the null values

# %%
percent_missing=data.isnull().sum()*100/len(data)

# %%
percent_missing
# Out:
# name            0.000000
# year            0.000000
# sellprice       0.000000
# kmdriven        0.000000
# fuel            0.000000
# sellertype      0.000000
# transmission    0.000000
# owner           0.000000
# mileage         4.040404
# engine          4.040404
# maxpower        4.040404
# torque          4.040404
# seats           4.040404
# dtype: float64

# %% [markdown]
# # How many columns are there in our dataset?

# %%
len(data.columns)
# Out:
# 13

# %% [markdown]
# # How many rows are there in our dataset?

# %%
len(data)
# Out:
# 99

# %% [markdown]
# # How many rows and columns are there in our dataset?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          99 non-null     object
#  1   year          99 non-null     int64
#  2   sellprice     99 non-null     int64
#  3   kmdriven      99 non-null     int64
#  4   fuel          99 non-null     object
#  5   sellertype    99 non-null     object
#  6   transmission  99 non-null     object
#  7   owner         99 non-null     object
#  8   mileage       95 non-null     object
#  9   engine        95 non-null     object
#  10  maxpower      95 non-null     object
#  11  torque        95 non-null     object
#  12  seats         95 non-null     float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 10.2+ KB

# %% [markdown]
# # Highest and lowest Sell Price

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data['sellprice']
# Out:
# 0     450000
# 1     370000
# 2     158000
# 3     225000
# 4     130000
#        ...
# 94    175000
# 95    525000
# 96    600000
# 97    565000
# 98    120000
# Name: sellprice, Length: 99, dtype: int64

# %% [markdown]
# # Highest Sell Price

# %%
data['sellprice'].max()
# Out:
# 2500000

# %% [markdown]
# # Lowest Sell Price

# %%
data['sellprice'].min()
# Out:
# 45000

# %% [markdown]
# # Average Sell Price

# %%
data['sellprice'].mean()
# Out:
# 584212.0808080808

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %% [markdown]
# # How Many People Have First Owner As Their Owner

# %%
data[data['owner']=='First Owner']
# Out:
#                                           name  year  sellprice  kmdriven  \
# 0                       Maruti Swift Dzire VDI  2014     450000    145500
# 3                    Hyundai i20 Sportz Diesel  2010     225000    127000
# 4                       Maruti Swift VXI BSIII  2007     130000    120000
# 5                Hyundai Xcent 1.2 VTVT E Plus  2017     440000     45000
# 6                 Maruti Wagon R LXI DUO BSIII  2007      96000    175000
# ..                                         ...   ...        ...       ...
# 91         Volkswagen Polo 1.2 MPI Comfortline  2015     455000     42000
# 94                 Maruti Zen Estilo LXI BSIII  2009     175000     55500
# 95  Hyundai i20 Asta Optional with Sunroof 1.2  2013     525000     61500
# 96                      Maruti Swift Dzire LDI  2016     600000    150000
# 97        Hyundai Xcent 1.2 Kappa SX Option AT  2016     565000     72000
#
#       fuel  sellertype transmission        owner     mileage   engine  \
# ...

# %% [markdown]
# # How Many People Have Dealer As Their Seller Type

# %%
data[data['sellertype']=='Dealer']
# Out:
#                                            name  year  sellprice  kmdriven  \
# 42                         Honda City i VTEC VX  2018     925000     28900
# 43                              Honda City V MT  2013     425000     86300
# 44                    Maruti Swift Dzire VXi AT  2018     675000     23300
# 45                     Maruti Vitara Brezza VDi  2018     819999     32600
# 46                          Maruti Alto K10 VXI  2018     390000     10300
# 47                       Toyota Fortuner 4x4 MT  2014    1500000     77000
# 48  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2013     700000     99000
# 49                   Mercedes-Benz B Class B180  2014    1450000     27800
# 50                         Honda Amaze S Diesel  2015     425000     49800
# 51                  Mitsubishi Pajero Sport 4X4  2013    1090000    151000
# 52                          Honda City i DTEC S  2015     600000     54700
# ...

# %% [markdown]
# # How Many Car Have Diesel As Their Fuel

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
len(data[data['fuel']=='Diesel'])
# Out:
# 48

# %% [markdown]
# # How Many Car Have Petrol As Their Fuel

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data[data['fuel']=='Petrol']
# Out:
#                                           name  year  sellprice  kmdriven  \
# 2                     Honda City 2017-2020 EXi  2006     158000    140000
# 4                       Maruti Swift VXI BSIII  2007     130000    120000
# 5                Hyundai Xcent 1.2 VTVT E Plus  2017     440000     45000
# 7                           Maruti 800 DX BSII  2001      45000      5000
# 11                               Maruti Zen LX  2005      92000    100000
# 13                        Maruti Swift 1.3 VXi  2007     200000     80000
# 14                    Maruti Wagon R LXI Minor  2009     180000     90000
# 15        Mahindra KUV 100 mFALCON G80 K8 5str  2016     400000     40000
# 18                              Maruti Alto LX  2002     150000     80000
# 24                     Tata Tigor 2017-2020 XZ  2018     500000     35000
# 25                     Maruti Baleno Delta 1.2  2016     575000     45000
# 26                         Maruti Alto 800 LXI  2017     275000     28000
# ...

# %%
len(data[data['fuel']=='Petrol'])
# Out:
# 48

# %%
data[data['fuel']=='Petrol'].count()
# Out:
# name            48
# year            48
# sellprice       48
# kmdriven        48
# fuel            48
# sellertype      48
# transmission    48
# owner           48
# mileage         46
# engine          46
# maxpower        46
# torque          46
# seats           46
# dtype: int64

# %% [markdown]
# # Transmission Title Contains Automatic

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data[data['transmission']=='Automatic']
# Out:
#                                     name  year  sellprice  kmdriven    fuel  \
# 41    Jeep Compass 1.4 Limited Plus BSIV  2019    2100000      5000  Petrol
# 44             Maruti Swift Dzire VXi AT  2018     675000     23300  Petrol
# 49            Mercedes-Benz B Class B180  2014    1450000     27800  Diesel
# 55   Toyota Innova Crysta 2.8 ZX AT BSIV  2016    1650000    127700  Diesel
# 57            Audi A6 2.0 TDI Technology  2013    1750000     33900  Diesel
# 58       Toyota Corolla Altis 1.8 VL CVT  2018    1590000     25000  Petrol
# 59       Audi A6 2.0 TDI  Design Edition  2013    1689999     50000  Diesel
# 60  Mercedes-Benz New C-Class 220 CDI AT  2013    1425000     59000  Diesel
# 69                Maruti Wagon R AMT VXI  2018     448000     30000  Petrol
# 72     Maruti Vitara Brezza ZDi Plus AMT  2019    1025000      9850  Diesel
# 82                BMW X1 sDrive20i xLine  2016    2500000     30000  Petrol
# ...

# %%
len(data[data['transmission']=='Automatic'])
# Out:
# 12

# %% [markdown]
# # Find Engine of The Car With The Following Torque:160Nm@ 2000rpm

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data[data['torque']=='160Nm@ 2000rpm']
# Out:
#                                     name  year  sellprice  kmdriven    fuel  \
# 9   Ford Figo Diesel Celebration Edition  2013     200000    169000  Diesel
# 20          Mahindra Verito 1.5 D4 BSIII  2011     174000    100000  Diesel
#
#     sellertype transmission         owner    mileage   engine  maxpower  \
# 9   Individual       Manual   First Owner  20.0 kmpl  1399 CC  68.1 bhp
# 20  Individual       Manual  Second Owner  21.0 kmpl  1461 CC  64.1 bhp
#
#             torque  seats
# 9   160Nm@ 2000rpm    5.0
# 20  160Nm@ 2000rpm    5.0

# %%
data[data['torque']=='160Nm@ 2000rpm']['engine']
# Out:
# 9     1399 CC
# 20    1461 CC
# Name: engine, dtype: object

# %% [markdown]
# # How many cars have Automatic as their First Owner And made a sell Price Rs 1500000

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data[(data['transmission']=='Automatic') & (data['sellprice']>1500000)]
# Out:
#                                    name  year  sellprice  kmdriven    fuel  \
# 41   Jeep Compass 1.4 Limited Plus BSIV  2019    2100000      5000  Petrol
# 55  Toyota Innova Crysta 2.8 ZX AT BSIV  2016    1650000    127700  Diesel
# 57           Audi A6 2.0 TDI Technology  2013    1750000     33900  Diesel
# 58      Toyota Corolla Altis 1.8 VL CVT  2018    1590000     25000  Petrol
# 59      Audi A6 2.0 TDI  Design Edition  2013    1689999     50000  Diesel
# 82               BMW X1 sDrive20i xLine  2016    2500000     30000  Petrol
#
#     sellertype transmission         owner     mileage   engine    maxpower  \
# 41  Individual    Automatic   First Owner   16.0 kmpl  1368 CC  160.77 bhp
# 55      Dealer    Automatic  Second Owner  11.36 kmpl  2755 CC   171.5 bhp
# 57      Dealer    Automatic  Second Owner  17.68 kmpl  1968 CC  174.33 bhp
# 58      Dealer    Automatic   First Owner  14.28 kmpl  1798 CC  138.03 bhp
# ...

# %%
len(data[(data['transmission']=='Automatic') & (data['sellprice']>1500000)])
# Out:
# 6

# %% [markdown]
# # Find torque of the car with the following Max Power No 189 bhp

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data[data['maxpower']=='189 bhp']
# Out:
#                       name  year  sellprice  kmdriven    fuel  sellertype  \
# 82  BMW X1 sDrive20i xLine  2016    2500000     30000  Petrol  Individual
#
#    transmission         owner     mileage   engine maxpower  \
# 82    Automatic  Second Owner  15.71 kmpl  1998 CC  189 bhp
#
#                  torque  seats
# 82  280Nm@ 1350-4600rpm    5.0

# %%
data[data['maxpower']=='189 bhp']['torque']
# Out:
# 82    280Nm@ 1350-4600rpm
# Name: torque, dtype: object

# %% [markdown]
# # How many cars are petrol How many cars are diesel How many cars LPG How many cars CNG

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data['fuel'].value_counts()
# Out:
# Diesel    48
# Petrol    48
# LPG        2
# CNG        1
# Name: fuel, dtype: int64

# %% [markdown]
# # How many transmission are manual & how many transmission are automatic

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data['transmission'].value_counts()
# Out:
# Manual       87
# Automatic    12
# Name: transmission, dtype: int64

# %% [markdown]
# # How many peopls have a buy car that year in 2011

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data[data['year']==2011]
# Out:
#                                name  year  sellprice  kmdriven    fuel  \
# 8                  Toyota Etios VXD  2011     350000     90000  Diesel
# 20     Mahindra Verito 1.5 D4 BSIII  2011     174000    100000  Diesel
# 39     Tata Safari DICOR 2.2 LX 4x2  2011     425000     60000  Diesel
# 61  Tata Manza ELAN Quadrajet BS IV  2011     265000    120000  Diesel
# 62                Hyundai i10 Magna  2011     190000    110000  Petrol
# 73                Hyundai i10 Magna  2011     235000     60000  Petrol
#
#     sellertype transmission         owner     mileage   engine    maxpower  \
# 8   Individual       Manual   First Owner  23.59 kmpl  1364 CC    67.1 bhp
# 20  Individual       Manual  Second Owner   21.0 kmpl  1461 CC    64.1 bhp
# 39  Individual       Manual  Second Owner  13.93 kmpl  2179 CC  138.03 bhp
# 61  Individual       Manual   First Owner  21.12 kmpl  1248 CC    88.8 bhp
# 62  Individual       Manual   Third Owner  20.36 kmpl  1197 CC    78.9 bhp
# ...

# %%
len(data[data['year']==2011])
# Out:
# 6

# %% [markdown]
# # How many car sale 2018 in Dealer Distributor ship

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data[(data['sellertype']=='Dealer') & (data['year']==2018)]
# Out:
#                                name  year  sellprice  kmdriven    fuel  \
# 42             Honda City i VTEC VX  2018     925000     28900  Petrol
# 44        Maruti Swift Dzire VXi AT  2018     675000     23300  Petrol
# 45         Maruti Vitara Brezza VDi  2018     819999     32600  Diesel
# 46              Maruti Alto K10 VXI  2018     390000     10300  Petrol
# 53                 Maruti Ciaz Zeta  2018     850000     64000  Petrol
# 58  Toyota Corolla Altis 1.8 VL CVT  2018    1590000     25000  Petrol
#
#    sellertype transmission        owner     mileage   engine    maxpower  \
# 42     Dealer       Manual  First Owner   17.8 kmpl  1497 CC   117.3 bhp
# 44     Dealer    Automatic  First Owner   18.5 kmpl  1197 CC   83.14 bhp
# 45     Dealer       Manual  First Owner   24.3 kmpl  1248 CC    88.5 bhp
# 46     Dealer       Manual  First Owner  23.95 kmpl   998 CC   67.05 bhp
# 53     Dealer       Manual  First Owner  20.65 kmpl  1462 CC  103.25 bhp
# ...

# %%
len(data[(data['sellertype']=='Dealer') & (data['year']==2018)])
# Out:
# 6

# %% [markdown]
# # Check For Duplicate Data and Drop Them

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          99 non-null     object
#  1   year          99 non-null     int64
#  2   sellprice     99 non-null     int64
#  3   kmdriven      99 non-null     int64
#  4   fuel          99 non-null     object
#  5   sellertype    99 non-null     object
#  6   transmission  99 non-null     object
#  7   owner         99 non-null     object
#  8   mileage       95 non-null     object
#  9   engine        95 non-null     object
#  10  maxpower      95 non-null     object
#  11  torque        95 non-null     object
#  12  seats         95 non-null     float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 10.2+ KB

# %%
dup=data.duplicated().any

# %%
print('is there any duplicated values',dup)
# Out:
# is there any duplicated values <bound method NDFrame._add_numeric_operations.<locals>.any of 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Length: 99, dtype: bool>

# %% [markdown]
# # Find Total Number of persons having year between 2007 to 2010 (inclusive) using between methods

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
sum(data['year'].between(2007,2010))
# Out:
# 10

# %% [markdown]
# # How many Cars having petrol diesel & Cng

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data1=data['fuel']=='Petrol'
data2=data['fuel']=='Diesel'
data3=data['fuel']=='CNG'

# %%
data[data1|data2|data3]
# Out:
#                                           name  year  sellprice  kmdriven  \
# 0                       Maruti Swift Dzire VDI  2014     450000    145500
# 1                 Skoda Rapid 1.5 TDI Ambition  2014     370000    120000
# 2                     Honda City 2017-2020 EXi  2006     158000    140000
# 3                    Hyundai i20 Sportz Diesel  2010     225000    127000
# 4                       Maruti Swift VXI BSIII  2007     130000    120000
# ..                                         ...   ...        ...       ...
# 94                 Maruti Zen Estilo LXI BSIII  2009     175000     55500
# 95  Hyundai i20 Asta Optional with Sunroof 1.2  2013     525000     61500
# 96                      Maruti Swift Dzire LDI  2016     600000    150000
# 97        Hyundai Xcent 1.2 Kappa SX Option AT  2016     565000     72000
# 98                        Maruti Alto LX BSIII  2008     120000     68000
#
#       fuel  sellertype transmission         owner     mileage   engine  \
# ...

# %%
len(data[data1|data2|data3])
# Out:
# 97

# %% [markdown]
# # Which Car getting the highest sell price

# %%
data.columns
# Out:
# Index(['name', 'year', 'sellprice', 'kmdriven', 'fuel', 'sellertype',
#        'transmission', 'owner', 'mileage', 'engine', 'maxpower', 'torque',
#        'seats'],
#       dtype='object')

# %%
data.groupby('name')['sellprice'].mean()
# Out:
# name
# Audi A6 2.0 TDI  Design Edition              1689999.0
# Audi A6 2.0 TDI Technology                   1750000.0
# BMW X1 sDrive20i xLine                       2500000.0
# Chevrolet Enjoy TCDi LTZ 7 Seater             300000.0
# Datsun GO A Petrol                            275000.0
#                                                ...
# Volkswagen Ameo 1.5 TDI Comfortline           500000.0
# Volkswagen Ameo 1.5 TDI Highline 16 Alloy     540000.0
# Volkswagen Polo 1.2 MPI Comfortline           455000.0
# Volkswagen Vento Diesel Highline              450000.0
# Volkswagen Vento Petrol Highline              535000.0
# Name: sellprice, Length: 92, dtype: float64
